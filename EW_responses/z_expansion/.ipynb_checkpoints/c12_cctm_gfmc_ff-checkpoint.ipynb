# %%
# Load libraries
import numpy as np
from scipy.optimize import curve_fit
from scipy import stats
import matplotlib.pyplot as plt
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
# Read response functions from file
nwR=5000
nq=25
wR=np.zeros(nwR)
qR=np.zeros(nq)
qR=np.asarray([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 
               1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000,
               2100,2200, 2300, 2400, 2500])

# %%
# Read one-body responses
R00_cc_1b=np.zeros( (nwR, nq, 3) )
R0z_cc_1b=np.zeros( (nwR, nq, 3) )
Rzz_cc_1b=np.zeros( (nwR, nq, 3) )
Rxx_cc_1b=np.zeros( (nwR, nq, 3) )
R00_cc_12b=np.zeros( (nwR, nq, 3) )
R0z_cc_12b=np.zeros( (nwR, nq, 3) )
Rzz_cc_12b=np.zeros( (nwR, nq, 3) )
Rxx_cc_12b=np.zeros( (nwR, nq, 3) )
Rxy_cc_1b=np.zeros( (nwR, nq, 3) )
Rxy_cc_12b=np.zeros( (nwR, nq, 3) )
R00_vec_1b=np.zeros( (nwR, nq, 3) )
R0z_vec_1b=np.zeros( (nwR, nq, 3) )
Rzz_vec_1b=np.zeros( (nwR, nq, 3) )
Rxx_vec_1b=np.zeros( (nwR, nq, 3) )
R00_vec_12b=np.zeros( (nwR, nq, 3) )
R0z_vec_12b=np.zeros( (nwR, nq, 3) )
Rzz_vec_12b=np.zeros( (nwR, nq, 3) )
Rxx_vec_12b=np.zeros( (nwR, nq, 3) )
Rxy_vec_1b=np.zeros( (nwR, nq, 3) )
Rxy_vec_12b=np.zeros( (nwR, nq, 3) )
R00_ax_1b=np.zeros( (nwR, nq, 3) )
R0z_ax_1b=np.zeros( (nwR, nq, 3) )
Rzz_ax_1b=np.zeros( (nwR, nq, 3) )
Rxx_ax_1b=np.zeros( (nwR, nq, 3) )
R00_ax_12b=np.zeros( (nwR, nq, 3) )
R0z_ax_12b=np.zeros( (nwR, nq, 3) )
Rzz_ax_12b=np.zeros( (nwR, nq, 3) )
Rxx_ax_12b=np.zeros( (nwR, nq, 3) )
Rxy_ax_1b=np.zeros( (nwR, nq, 3) )
Rxy_ax_12b=np.zeros( (nwR, nq, 3) )

qname = ['q_100/', 'q_200/', 'q_300/', 'q_400/', 'q_500/','q_600/', 'q_700/']
fname_cc_00_1b = []
fname_cc_0z_1b = []
fname_cc_zz_1b = []
fname_cc_xx_1b = []
fname_cc_xy_1b = []
fname_cc_00_12b = []
fname_cc_0z_12b = []
fname_cc_zz_12b = []
fname_cc_xx_12b = []
fname_cc_xy_12b = []
#
fname_vec_00_1b = []
fname_vec_0z_1b = []
fname_vec_zz_1b = []
fname_vec_xx_1b = []
fname_vec_xy_1b = []
fname_vec_00_12b = []
fname_vec_0z_12b = []
fname_vec_zz_12b = []
fname_vec_xx_12b = []
fname_vec_xy_12b = []
#ff = '_hohler/'
ff = 'c12_gfmc/'
for i in range (0,7):
    fname_cc_00_1b.append(ff + qname [i] + 'nc_rr_1b.out') 
    fname_cc_0z_1b.append(ff + qname [i] + 'nc_0z_1b.out') 
    fname_cc_zz_1b.append(ff + qname [i] + 'nc_zz_1b.out') 
    fname_cc_xx_1b.append(ff + qname [i] + 'nc_xx_1b.out') 
    fname_cc_xy_1b.append(ff + qname [i] + 'nc_xy_1b.out') 
    fname_cc_00_12b.append( ff + qname [i] + 'nc_rr_12b.out') 
    fname_cc_0z_12b.append(ff + qname [i] + 'nc_0z_12b.out') 
    fname_cc_zz_12b.append(ff + qname [i] + 'nc_zz_12b.out') 
    fname_cc_xx_12b.append(ff + qname [i] + 'nc_xx_12b.out') 
    fname_cc_xy_12b.append(ff + qname [i] + 'nc_xy_12b.out') 
for i in range (0,7):
    data_cc_00_1b = np.loadtxt(fname_cc_00_1b[i], unpack=True, skiprows=1)
    data_cc_0z_1b = np.loadtxt(fname_cc_0z_1b[i], unpack=True, skiprows=1)
    data_cc_zz_1b = np.loadtxt(fname_cc_zz_1b[i], unpack=True, skiprows=1)
    data_cc_xx_1b = np.loadtxt(fname_cc_xx_1b[i], unpack=True, skiprows=1) 
    data_cc_xy_1b = np.loadtxt(fname_cc_xy_1b[i], unpack=True, skiprows=1)    
    data_cc_00_12b = np.loadtxt(fname_cc_00_12b[i], unpack=True, skiprows=1)
    data_cc_0z_12b = np.loadtxt(fname_cc_0z_12b[i], unpack=True, skiprows=1)
    data_cc_zz_12b = np.loadtxt(fname_cc_zz_12b[i], unpack=True, skiprows=1)
    data_cc_xx_12b = np.loadtxt(fname_cc_xx_12b[i], unpack=True, skiprows=1)  
    data_cc_xy_12b = np.loadtxt(fname_cc_xy_12b[i], unpack=True, skiprows=1)   
    wR[:]=data_cc_00_1b[0,:]
    for j in range (3):
        R00_cc_1b[:,i,j]=data_cc_00_1b[j+1,:]
        R0z_cc_1b[:,i,j]=data_cc_0z_1b[j+1,:]
        Rzz_cc_1b[:,i,j]=data_cc_zz_1b[j+1,:]
        Rxx_cc_1b[:,i,j]=data_cc_xx_1b[j+1,:]
        Rxy_cc_1b[:,i,j]=data_cc_xy_1b[j+1,:]               
        R00_cc_12b[:,i,j]=data_cc_00_12b[j+1,:]
        R0z_cc_12b[:,i,j]=data_cc_0z_12b[j+1,:]
        Rzz_cc_12b[:,i,j]=data_cc_zz_12b[j+1,:]
        Rxx_cc_12b[:,i,j]=data_cc_xx_12b[j+1,:]  
        Rxy_cc_12b[:,i,j]=data_cc_xy_12b[j+1,:]    
#
for i in range (0,7):
    fname_vec_00_1b.append(ff + qname [i] + 'vect_rr_1b.out') 
    fname_vec_0z_1b.append(ff + qname [i] + 'vect_0z_1b.out') 
    fname_vec_zz_1b.append(ff + qname [i] + 'vect_zz_1b.out') 
    fname_vec_xx_1b.append(ff + qname [i] + 'vect_xx_1b.out') 
    fname_vec_xy_1b.append(ff + qname [i] + 'vect_xy_1b.out') 
    fname_vec_00_12b.append( ff + qname [i] + 'vect_rr_12b.out') 
    fname_vec_0z_12b.append(ff + qname [i] + 'vect_0z_12b.out') 
    fname_vec_zz_12b.append(ff + qname [i] + 'vect_zz_12b.out') 
    fname_vec_xx_12b.append(ff + qname [i] + 'vect_xx_12b.out') 
    fname_vec_xy_12b.append(ff + qname [i] + 'vect_xy_12b.out') 
for i in range (0,7):
    data_vec_00_1b = np.loadtxt(fname_vec_00_1b[i], unpack=True, skiprows=1)
    data_vec_0z_1b = np.loadtxt(fname_vec_0z_1b[i], unpack=True, skiprows=1)
    data_vec_zz_1b = np.loadtxt(fname_vec_zz_1b[i], unpack=True, skiprows=1)
    data_vec_xx_1b = np.loadtxt(fname_vec_xx_1b[i], unpack=True, skiprows=1) 
    data_vec_xy_1b = np.loadtxt(fname_vec_xy_1b[i], unpack=True, skiprows=1)    
    data_vec_00_12b = np.loadtxt(fname_vec_00_12b[i], unpack=True, skiprows=1)
    data_vec_0z_12b = np.loadtxt(fname_vec_0z_12b[i], unpack=True, skiprows=1)
    data_vec_zz_12b = np.loadtxt(fname_vec_zz_12b[i], unpack=True, skiprows=1)
    data_vec_xx_12b = np.loadtxt(fname_vec_xx_12b[i], unpack=True, skiprows=1)  
    data_vec_xy_12b = np.loadtxt(fname_vec_xy_12b[i], unpack=True, skiprows=1)   

    for j in range (3):
        R00_vec_1b[:,i,j]=data_vec_00_1b[j+1,:]
        R0z_vec_1b[:,i,j]=data_vec_0z_1b[j+1,:]
        Rzz_vec_1b[:,i,j]=data_vec_zz_1b[j+1,:]
        Rxx_vec_1b[:,i,j]=data_vec_xx_1b[j+1,:]
        Rxy_vec_1b[:,i,j]=data_vec_xy_1b[j+1,:]               
        R00_vec_12b[:,i,j]=data_vec_00_12b[j+1,:]
        R0z_vec_12b[:,i,j]=data_vec_0z_12b[j+1,:]
        Rzz_vec_12b[:,i,j]=data_vec_zz_12b[j+1,:]
        Rxx_vec_12b[:,i,j]=data_vec_xx_12b[j+1,:]  
        Rxy_vec_12b[:,i,j]=data_vec_xy_12b[j+1,:]

# %%
R00_ax_1b=R00_cc_1b-R00_vec_1b
R0z_ax_1b=R0z_cc_1b-R0z_vec_1b
Rzz_ax_1b=Rzz_cc_1b-Rzz_vec_1b
Rxx_ax_1b=Rxx_cc_1b-Rxx_vec_1b
Rxy_ax_1b=Rxy_cc_1b-Rxy_vec_1b
R00_ax_12b=R00_cc_12b-R00_vec_12b
R0z_ax_12b=R0z_cc_12b-R0z_vec_12b
Rzz_ax_12b=Rzz_cc_12b-Rzz_vec_12b
Rxx_ax_12b=Rxx_cc_12b-Rxx_vec_12b
Rxy_ax_12b=Rxy_cc_12b-Rxy_vec_12b

#Fixing w dependence in the zz and 0z channels

for i in range (0,7):
    for j in range (nwR):
        Rzz_vec_1b[j,i,:]=(wR[j]/qR[i])**2*R00_vec_1b[j,i,:]
        R0z_vec_1b[j,i,:]=2*(wR[j]/qR[i])*R00_vec_1b[j,i,:]
        Rzz_vec_12b[j,i,:]=(wR[j]/qR[i])**2*R00_vec_12b[j,i,:]
        R0z_vec_12b[j,i,:]=2*(wR[j]/qR[i])*R00_vec_12b[j,i,:]
        #
        Rzz_cc_1b[j,i,:]=Rzz_vec_1b[j,i,:]+Rzz_ax_1b[j,i,:]
        R0z_cc_1b[j,i,:]=R0z_vec_1b[j,i,:]+R0z_ax_1b[j,i,:]
        Rzz_cc_12b[j,i,:]=Rzz_vec_12b[j,i,:]+Rzz_ax_12b[j,i,:]
        R0z_cc_12b[j,i,:]=R0z_vec_12b[j,i,:]+R0z_ax_12b[j,i,:]
        

        #  R_zz(1,:,i)=(w(i)/qval)**2*R_00(1,:,i)
       #R_0z(1,:,i)=2.0d0*(w(i)/qval)*R_00(1,:,i)
       #R_zz(3,:,i)=R_zz(2,:,i)+R_zz(1,:,i)
       #R_0z(3,:,i)=R_0z(2,:,i)+R_0z(1,:,i)

# %% [markdown]
# ## Scaling analysis
# Here we analyze how the response functions scale to obtain responses at q > 700 MeV/c. Instead of using the Fermi Gas scaling factors, we utilize those obtained from PWIA calculations

# %%
eps=40.
mn=938.95
mpi=139.
kF=260.
y=np.zeros((nwR,nq))
for i in range (nwR):
    for j in range (nq):
        y[i,j]=mn/qR[j]/kF*(wR[i]-qR[j]**2/2/mn-eps)

# %%
fname = 'ff_kelly.dat'
data = np.loadtxt(fname, unpack=True, skiprows=0)
nQ2 = len(data[0,:])
Q2 =  np.zeros(nQ2)
ges = np.zeros(nQ2)
gms = np.zeros(nQ2)
gev = np.zeros(nQ2)
gmv = np.zeros(nQ2)
ga = np.zeros(nQ2)
Q2 = data[0,:]
ges = data[1,:]
gms = data[2,:]
gev = data[3,:]
gmv = data[4,:]
ga = data[5,:]
plt.plot(Q2/10**6,gev**2, color='blue')
plt.plot(Q2/10**6,ga**2 )
plt.plot(Q2/10**6,gmv**2, color='red' )
plt.yscale('log')
plt.show()

# %%
from scipy import interpolate
ges_interpolate = interpolate.InterpolatedUnivariateSpline(Q2, ges)
gms_interpolate = interpolate.InterpolatedUnivariateSpline(Q2, gms)
gev_interpolate = interpolate.InterpolatedUnivariateSpline(Q2, gev)
gmv_interpolate = interpolate.InterpolatedUnivariateSpline(Q2, gmv)
ga_interpolate = interpolate.InterpolatedUnivariateSpline(Q2, ga)

# %%
wqe = np.sqrt(qR**2+mn**2)-mn
Q2qe = qR**2 - wqe**2
tauqe = Q2qe/4/mn**2

# %%
for i in range (nq):
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Gev_qe = gev_interpolate(Q2qe)
    Gmv_qe = gmv_interpolate(Q2qe)
    GA_qe = ga_interpolate(Q2qe)
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2 - wj**2)
        Gevj = gev_interpolate(Q2j)
        Gmvj = gmv_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        
        f_A=GAj**2/GA_qe**2
        f_V=Gevj**2/Gev_qe**2
        f_VM=Gmvj**2/Gmv_qe**2
        
        R00_cc_1b[j,i,:]=R00_vec_1b[j,i,:]*f_V+R00_ax_1b[j,i,:]*f_A
        Rxx_cc_1b[j,i,:]=Rxx_vec_1b[j,i,:]*f_VM+Rxx_ax_1b[j,i,:]*f_A
        Rzz_cc_1b[j,i,:]=Rzz_vec_1b[j,i,:]*f_V+Rzz_ax_1b[j,i,:]*f_A
        R0z_cc_1b[j,i,:]=R0z_vec_1b[j,i,:]*f_V+R0z_ax_1b[j,i,:]*f_A
        Rxy_cc_1b[j,i,:]=Rxy_cc_1b[j,i,:]*np.sqrt(f_A)*np.sqrt(f_VM)
        #
        R00_cc_12b[j,i,:]=R00_vec_12b[j,i,:]*f_V+R00_ax_12b[j,i,:]*f_A
        Rxx_cc_12b[j,i,:]=Rxx_vec_12b[j,i,:]*f_VM+Rxx_ax_12b[j,i,:]*f_A
        Rzz_cc_12b[j,i,:]=Rzz_vec_12b[j,i,:]*f_V+Rzz_ax_12b[j,i,:]*f_A
        R0z_cc_12b[j,i,:]=R0z_vec_12b[j,i,:]*f_V+R0z_ax_12b[j,i,:]*f_A
        Rxy_cc_12b[j,i,:]=Rxy_cc_12b[j,i,:]*np.sqrt(f_A)*np.sqrt(f_VM)

# %% [markdown]
# ## $R_{00}$ - one body

# %%
eps=50.
mn=939.
mpi=139.
kF=260.
mstar=1.0
y=np.zeros((nwR,nq))
for i in range (nwR):
    for j in range (nq):
        y[i,j]=mn/qR[j]/kF*(wR[i]-qR[j]**2/2/(mn*mstar)-eps)
G00_vc = np.zeros((nq,nwR))
G00_ac = np.zeros((nq,nwR))
G00_cc = np.zeros((nq,nwR))
G00_cc_min = np.zeros(nq)
for i in range (nq):
    first_time = 1
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Ges = ges_interpolate(Q2qe)
    Gev = gev_interpolate(Q2qe)
    Gmv = gmv_interpolate(Q2qe)
    Gms = gms_interpolate(Q2qe)
    GA = ga_interpolate(Q2qe)
    gps = GA / (mpi**2 + Q2qe)  
    Gen = (Ges - Gev) / 2
    Gep = (Ges + Gev) / 2
    Gmn = (Gms - Gmv) / 2
    Gmp = (Gms + Gmv) / 2
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2 - wj**2)
        Gevj = gev_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        pG = mn/qR[i]*(wR[j]-qR[i]**2/2/mn-eps)
        if pG > kF: pG = kF
        G00_vc[i,j] = (((Gen-Gep-2*Gmn+2*Gmp)**2*(kF-pG)*(kF+pG)*qR[i]**2)/(32*mn**4)+(Gen-Gep)**2/(1+tauqe[i]))/qR[i]
        G00_ac[i,j] = ((GA**2*(2*(kF**2+pG**2)+4*pG*qR[i]+qR[i]**2))/(4*mn**2)-(GA*gps*qR[i]*(2*pG+qR[i])*wqe[i])/mn
                    + gps**2*qR[i]**2*wqe[i]**2)/qR[i]
        G00_cc[i,j] = G00_vc[i,j]*Gevj**2/Gev**2 + G00_ac[i,j]*GAj**2/GA**2   
        if  y[j,i] > -0.9 and first_time == 1:
            first_time = 0
            G00_cc_min[i] = G00_cc[i,j]   
for i in range (nq):
    for j in range (nwR):
        if  y[j,i] < -0.9: G00_cc[i,j] = G00_cc_min[i]
        G00_cc[i,j] = G00_cc[i,j] / kF * ( mn * 6 )

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], R00_cc_1b[:,i,2], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R00_cc_1b[:,i,1], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R00_cc_1b[:,i,0], color=palette(i), linestyle='-.')
#    plt.plot(y[:,i],3/4*(1-y[:,i]**2))
plt.xlim(-1.5,3)
#plt.ylim(0,0.9)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], R0z_cc_1b[:,i,2], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R0z_cc_1b[:,i,1], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R0z_cc_1b[:,i,0], color=palette(i), linestyle='-.')
#    plt.plot(y[:,i],3/4*(1-y[:,i]**2))
plt.xlim(-1.5,3)
#plt.ylim(0,0.9)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rxx_cc_1b[:,i,2], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rxx_cc_1b[:,i,1], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rxx_cc_1b[:,i,0], color=palette(i), linestyle='-.')
#    plt.plot(y[:,i],3/4*(1-y[:,i]**2))
plt.xlim(-1.5,3)
#plt.ylim(0,0.9)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rzz_cc_1b[:,i,2], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rzz_cc_1b[:,i,1], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rzz_cc_1b[:,i,0], color=palette(i), linestyle='-.')
#    plt.plot(y[:,i],3/4*(1-y[:,i]**2))
plt.xlim(-1.5,3)
#plt.ylim(0,0.9)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], R00_cc_1b[:,i,2]/G00_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R00_cc_1b[:,i,1]/G00_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R00_cc_1b[:,i,0]/G00_cc[i,:], color=palette(i), linestyle='-.')
#    plt.plot(y[:,i],3/4*(1-y[:,i]**2))
plt.xlim(-1.5,3)
#plt.ylim(0,0.9)
plt.legend(loc=1, ncol=2)
plt.show() 
data=np.array([y[:,4],R00_cc_1b[:,4,0]/G00_cc[4,:],R00_cc_1b[:,4,2]/G00_cc[4,:],R00_cc_1b[:,4,1]/G00_cc[4,:],
               y[:,5],R00_cc_1b[:,5,0]/G00_cc[5,:],R00_cc_1b[:,5,2]/G00_cc[5,:],R00_cc_1b[:,5,1]/G00_cc[5,:],
               y[:,6],R00_cc_1b[:,6,0]/G00_cc[6,:],R00_cc_1b[:,6,2]/G00_cc[6,:],R00_cc_1b[:,6,1]/G00_cc[6,:]])
data = data.T
np.savetxt('F_00_1b.dat', data)

# %%
R00_cc_1b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], R00_cc_1b[:,6,2]/G00_cc[6,:])
R00_cc_1b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], R00_cc_1b[:,5,2]/G00_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        R00_cc_1b[i,j,0] = R00_cc_1b_interpolate_600(y[i,j])*G00_cc[j,i]
        R00_cc_1b[i,j,2] = R00_cc_1b_interpolate_700(y[i,j])*G00_cc[j,i]
        err =  2 * (R00_cc_1b[i,j,2] - R00_cc_1b[i,j,0])
        R00_cc_1b[i,j,1] = R00_cc_1b[i,j,2] + err
        R00_cc_1b[i,j,0] = R00_cc_1b[i,j,2] - err
        if y[i,j] < y[0,6]:
            R00_cc_1b[i,j,:] = 0
        for k in range(3):
            if R00_cc_1b[i,j,k] < 0:  R00_cc_1b[i,j,k] = 0

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,nq):
    plt.plot(y[:,i], R00_cc_1b[:,i,2]/G00_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R00_cc_1b[:,i,1]/G00_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R00_cc_1b[:,i,0]/G00_cc[i,:], color=palette(i), linestyle='-.')
#    plt.plot(y[:,i],3/4*(1-y[:,i]**2))
plt.xlim(-1.5,3)
#plt.ylim(0,0.9)
plt.legend(loc=1, ncol=2)
plt.show()

# %% [markdown]
# ## $R_{00}$ - one-two body

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], R00_cc_12b[:,i,2]/G00_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R00_cc_12b[:,i,1]/G00_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R00_cc_12b[:,i,0]/G00_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
plt.legend(loc=1, ncol=2)
plt.show() 
data=np.array([y[:,4],R00_cc_12b[:,4,0]/G00_cc[4,:],R00_cc_12b[:,4,2]/G00_cc[4,:],R00_cc_12b[:,4,1]/G00_cc[4,:],
               y[:,5],R00_cc_12b[:,5,0]/G00_cc[5,:],R00_cc_12b[:,5,2]/G00_cc[5,:],R00_cc_12b[:,5,1]/G00_cc[5,:],
               y[:,6],R00_cc_12b[:,6,0]/G00_cc[6,:],R00_cc_12b[:,6,2]/G00_cc[6,:],R00_cc_12b[:,6,1]/G00_cc[6,:]])
data = data.T
np.savetxt('F_00_12b.dat', data)

# %%
R00_cc_12b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], R00_cc_12b[:,6,2]/G00_cc[6,:])
R00_cc_12b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], R00_cc_12b[:,5,2]/G00_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        R00_cc_12b[i,j,0] = R00_cc_12b_interpolate_600(y[i,j])*G00_cc[j,i]
        R00_cc_12b[i,j,2] = R00_cc_12b_interpolate_700(y[i,j])*G00_cc[j,i]
        err = 2 * (R00_cc_12b[i,j,2] - R00_cc_12b[i,j,0])
        R00_cc_12b[i,j,1] = R00_cc_12b[i,j,2] + err
        R00_cc_12b[i,j,0] = R00_cc_12b[i,j,2] - err
        if y[i,j] < y[0,6]:
            R00_cc_12b[i,j,:] = 0
        for k in range(3):
            if R00_cc_12b[i,j,k] < 0:  R00_cc_12b[i,j,k] = 0

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,nq):
    plt.plot(y[:,i], R00_cc_12b[:,i,2]/G00_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R00_cc_12b[:,i,1]/G00_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R00_cc_12b[:,i,0]/G00_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
plt.legend(loc=1, ncol=2)
plt.show()

# %% [markdown]
# ## $R_{0z}$ - one body

# %%
G0z_vc = np.zeros((nq,nwR))
G0z_ac = np.zeros((nq,nwR))
G0z_cc = np.zeros((nq,nwR))
G0z_cc_min = np.zeros(nq)
for i in range (nq):
    first_time = 1
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Ges = ges_interpolate(Q2qe)
    Gev = gev_interpolate(Q2qe)
    Gmv = gmv_interpolate(Q2qe)
    Gms = gms_interpolate(Q2qe)
    GA = ga_interpolate(Q2qe)
    gps = GA / (mpi**2 + Q2qe)  
    Gen = (Ges - Gev) / 2
    Gep = (Ges + Gev) / 2
    Gmn = (Gms - Gmv) / 2
    Gmp = (Gms + Gmv) / 2
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2-wj**2)
        Gevj = gev_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        pG = mn/qR[i]*(wR[j]-qR[i]**2/2/mn-eps)
        if pG > 3*kF: pG = 3*kF
        G0z_vc[i,j] = wR[j]/qR[i]*G00_vc[i,j]
        G0z_ac[i,j] = ((GA**2*(4*mn**2*(2*pG+qR[i])+qR[i]*(kF**2+(pG+qR[i])*(3*pG+qR[i])))+8*gps**2*mn**3*qR[i]**3*wqe[i]
                    - 2*GA*gps*mn*qR[i]*(2*mn*qR[i]*(2*pG+qR[i])+(-kF**2+4*mn**2+(pG+qR[i])**2)*wqe[i]))/(8*mn**3))/qR[i]
        G0z_cc[i,j] = G0z_vc[i,j]*Gevj**2/Gev**2 + G0z_ac[i,j]*GAj**2/GA**2
        if  y[j,i] > -0.9 and first_time == 1:
            first_time = 0
            G0z_cc_min[i] = G0z_cc[i,j]   
for i in range (nq):
    for j in range (nwR):
        if  y[j,i] < -0.9: G0z_cc[i,j] = G0z_cc_min[i]
        G0z_cc[i,j] = G0z_cc[i,j] / kF * ( mn * 6 )

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], R0z_cc_1b[:,i,2]/G0z_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R0z_cc_1b[:,i,1]/G0z_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R0z_cc_1b[:,i,0]/G0z_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
#plt.ylim(-4,35)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
R0z_cc_1b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], R0z_cc_1b[:,6,2]/G0z_cc[6,:])
R0z_cc_1b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], R0z_cc_1b[:,5,2]/G0z_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        R0z_cc_1b[i,j,0] = R0z_cc_1b_interpolate_600(y[i,j])*G0z_cc[j,i]
        R0z_cc_1b[i,j,2] = R0z_cc_1b_interpolate_700(y[i,j])*G0z_cc[j,i]
        err = 2 * (R0z_cc_1b[i,j,2] - R0z_cc_1b[i,j,0])
        R0z_cc_1b[i,j,1] = R0z_cc_1b[i,j,2] + err
        R0z_cc_1b[i,j,0] = R0z_cc_1b[i,j,2] - err
        if y[i,j] < y[0,6]:
            R0z_cc_1b[i,j,:] = 0

# %% [markdown]
# ## $R_{0z}$ - one+two body

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], R0z_cc_12b[:,i,2]/G0z_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], R0z_cc_12b[:,i,1]/G0z_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], R0z_cc_12b[:,i,0]/G0z_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
#plt.ylim(-2,35)
plt.legend(loc=1, ncol=2) 
plt.show()

# %%
R0z_cc_12b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], R0z_cc_12b[:,6,2]/G0z_cc[6,:])
R0z_cc_12b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], R0z_cc_12b[:,5,2]/G0z_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        R0z_cc_12b[i,j,0] = R0z_cc_12b_interpolate_600(y[i,j])*G0z_cc[j,i]
        R0z_cc_12b[i,j,2] = R0z_cc_12b_interpolate_700(y[i,j])*G0z_cc[j,i]
        err = 2 * (R0z_cc_12b[i,j,2] - R0z_cc_12b[i,j,0])
        R0z_cc_12b[i,j,1] = R0z_cc_12b[i,j,2] + err
        R0z_cc_12b[i,j,0] = R0z_cc_12b[i,j,2] - err
        if y[i,j] < y[0,6]:
            R0z_cc_12b[i,j,:] = 0

# %% [markdown]
# ## $R_{zz}$ one body

# %%
Gzz_vc = np.zeros((nq,nwR))
Gzz_vc_qe = np.zeros((nq,nwR))
Gzz_ac = np.zeros((nq,nwR))
Gzz_cc = np.zeros((nq,nwR))
Gzz_cc_min = np.zeros(nq)
for i in range (nq):
    first_time = 1
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Ges = ges_interpolate(Q2qe)
    Gev = gev_interpolate(Q2qe)
    Gmv = gmv_interpolate(Q2qe)
    Gms = gms_interpolate(Q2qe)
    GA =  ga_interpolate(Q2qe)
    gps = GA / (mpi**2 + Q2qe)  
    Gen = (Ges - Gev) / 2
    Gep = (Ges + Gev) / 2
    Gmn = (Gms - Gmv) / 2
    Gmp = (Gms + Gmv) / 2
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2 - wj**2)
        Gevj = gev_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        pG = mn/qR[i]*(wR[j]-qR[i]**2/2/mn-eps)
        if pG > kF: pG = kF
        Gzz_vc[i,j] = wR[j]**2/qR[i]**2*G00_vc[i,j]
        Gzz_ac[i,j] = (gps**2*qR[i]**4-(GA*gps*qR[i]**2*(-kF**2+4*mn**2+(pG+qR[i])**2))/(2*mn**2)
                    +(GA**2*(4*kF**4+48*mn**4-2*pG**4-2*kF**2*(12*mn**2+pG**2)+12*pG**2*qR[i]**2+12*pG*qR[i]**3
                    +3*qR[i]**4+24*mn**2*(pG+qR[i])**2))/(48.*mn**4))/qR[i]
        Gzz_cc[i,j] = Gzz_vc[i,j]*Gevj**2/Gev**2 + Gzz_ac[i,j]*GAj**2/GA**2
        if  y[j,i] > -0.8 and first_time == 1:
            first_time = 0
            Gzz_cc_min[i] = Gzz_cc[i,j]   
for i in range (nq):
    for j in range (nwR):
        if  y[j,i] < -0.8: Gzz_cc[i,j] = Gzz_cc_min[i]
        Gzz_cc[i,j] = Gzz_cc[i,j] / kF * ( mn * 6 )

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rzz_cc_1b[:,i,2]/Gzz_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rzz_cc_1b[:,i,1]/Gzz_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rzz_cc_1b[:,i,0]/Gzz_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
Rzz_cc_1b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], Rzz_cc_1b[:,6,2]/Gzz_cc[6,:])
Rzz_cc_1b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], Rzz_cc_1b[:,5,2]/Gzz_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        Rzz_cc_1b[i,j,0] = Rzz_cc_1b_interpolate_600(y[i,j])*Gzz_cc[j,i]
        Rzz_cc_1b[i,j,2] = Rzz_cc_1b_interpolate_700(y[i,j])*Gzz_cc[j,i]
        err = 2 * (Rzz_cc_1b[i,j,2] - Rzz_cc_1b[i,j,0])
        Rzz_cc_1b[i,j,1] = Rzz_cc_1b[i,j,2] + err
        Rzz_cc_1b[i,j,0] = Rzz_cc_1b[i,j,2] - err
        if y[i,j] < y[0,6]:
            Rzz_cc_1b[i,j,:] = 0
        for k in range(3):
            if Rzz_cc_1b[i,j,k] < 0:  Rzz_cc_1b[i,j,k] = 0

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,nq):
    plt.plot(y[:,i], Rzz_cc_1b[:,i,2]/Gzz_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rzz_cc_1b[:,i,1]/Gzz_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rzz_cc_1b[:,i,0]/Gzz_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
plt.legend(loc=1, ncol=2)
plt.show()

# %% [markdown]
# ## $R_{zz}$ one+two body

# %%
eps=50.
mn=939.
mpi=139.
kF=260.
mstar=1.0
y=np.zeros((nwR,nq))
for i in range (nwR):
    for j in range (nq):
        y[i,j]=mn/qR[j]/kF*(wR[i]-qR[j]**2/2/(mn*mstar)-eps)
Gzz_vc = np.zeros((nq,nwR))
Gzz_ac = np.zeros((nq,nwR))
Gzz_cc = np.zeros((nq,nwR))
Gzz_cc_min = np.zeros(nq)
for i in range (nq):
    first_time = 1
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Ges = ges_interpolate(Q2qe)
    Gev = gev_interpolate(Q2qe)
    Gmv = gmv_interpolate(Q2qe)
    Gms = gms_interpolate(Q2qe)
    GA =  ga_interpolate(Q2qe)
    gps = GA / (mpi**2 + Q2qe)  
    Gen = (Ges - Gev) / 2
    Gep = (Ges + Gev) / 2
    Gmn = (Gms - Gmv) / 2
    Gmp = (Gms + Gmv) / 2
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2 - wj**2)
        Gevj = gev_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        pG = mn/qR[i]*(wR[j]-qR[i]**2/2/mn-eps)
        if pG > kF: pG = kF
        Gzz_vc[i,j] = wR[j]**2/qR[i]**2*G00_vc[i,j]
        Gzz_ac[i,j] = (gps**2*qR[i]**4-(GA*gps*qR[i]**2*(-kF**2+4*mn**2+(pG+qR[i])**2))/(2*mn**2)
                    +(GA**2*(4*kF**4+48*mn**4-2*pG**4-2*kF**2*(12*mn**2+pG**2)+12*pG**2*qR[i]**2+12*pG*qR[i]**3
                    +3*qR[i]**4+24*mn**2*(pG+qR[i])**2))/(48.*mn**4))/qR[i]
        Gzz_cc[i,j] = Gzz_vc[i,j]*Gevj**2/Gev**2 + Gzz_ac[i,j]*GAj**2/GA**2
        if  y[j,i] > -1. and first_time == 1:
            first_time = 0
            Gzz_cc_min[i] = Gzz_cc[i,j]   
for i in range (nq):
    for j in range (nwR):
        if  y[j,i] < -1.: Gzz_cc[i,j] = Gzz_cc_min[i]
        Gzz_cc[i,j] = Gzz_cc[i,j] / kF * ( mn * 6 )

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rzz_cc_12b[:,i,2]/G0z_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rzz_cc_12b[:,i,1]/G0z_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rzz_cc_12b[:,i,0]/G0z_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3)
#plt.ylim(-1,15)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
Rzz_cc_12b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], Rzz_cc_12b[:,6,2]/G0z_cc[6,:])
Rzz_cc_12b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], Rzz_cc_12b[:,5,2]/G0z_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        Rzz_cc_12b[i,j,0] = Rzz_cc_12b_interpolate_600(y[i,j])*G0z_cc[j,i]
        Rzz_cc_12b[i,j,2] = Rzz_cc_12b_interpolate_700(y[i,j])*G0z_cc[j,i]
        err = 2 * (Rzz_cc_12b[i,j,2] - Rzz_cc_12b[i,j,0])
        Rzz_cc_12b[i,j,1] = Rzz_cc_12b[i,j,2] + err
        Rzz_cc_12b[i,j,0] = Rzz_cc_12b[i,j,2] - err
        if y[i,j] < y[0,6]:
            Rzz_cc_12b[i,j,:] = 0
        for k in range(3):
            if Rzz_cc_12b[i,j,k] < 0:  Rzz_cc_12b[i,j,k] = 0

# %% [markdown]
# ## $R_{xx}$ one body

# %%
eps=50.
mn=939.
mpi=139.
kF=260.
mstar=1.0
y=np.zeros((nwR,nq))
for i in range (nwR):
    for j in range (nq):
        y[i,j]=mn/qR[j]/kF*(wR[i]-qR[j]**2/2/(mn*mstar)-eps)
Gxx_vc = np.zeros((nq,nwR))
Gxx_ac = np.zeros((nq,nwR))
Gxx_cc = np.zeros((nq,nwR))
Gxx_cc_min = np.zeros(nq)
for i in range (nq):
    first_time = 1
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Ges = ges_interpolate(Q2qe)
    Gev = gev_interpolate(Q2qe)
    Gmv = gmv_interpolate(Q2qe)
    Gms = gms_interpolate(Q2qe)
    GA =  ga_interpolate(Q2qe)
    gps = GA / (mpi**2 + Q2qe)  
    Gen = (Ges - Gev) / 2
    Gep = (Ges + Gev) / 2
    Gmn = (Gms - Gmv) / 2
    Gmp = (Gms + Gmv) / 2
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2 - wj**2)
        Gevj = gev_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        pG = mn/qR[i]*(wR[j]-qR[i]**2/2/mn-eps)
        if pG > kF: pG = kF
        Gxx_vc[i,j] =(((Gen-Gep)**2*(kF-pG)*(kF+pG)+(Gmn-Gmp)**2*qR[i]**2)/(4*mn**2))/qR[i]
        Gxx_ac[i,j] = ((GA**2*(2*kF**4+48*mn**4+5*pG**4+12*pG**3*qR[i]+18*pG**2*qR[i]**2+12*pG*qR[i]**3
                    + 3*qR[i]**4-12*mn**2*(3*pG**2+4*pG*qR[i]+2*qR[i]**2)+kF**2*(-12*mn**2+5*pG**2
                    + 12*pG*qR[i]+6*qR[i]**2)))/(48.*mn**4))/qR[i]
        Gxx_cc[i,j] = Gxx_vc[i,j]*Gevj**2/Gev**2 + Gxx_ac[i,j]*GAj**2/GA**2
        if  y[j,i] > -0.9 and first_time == 1:
            first_time = 0
            Gxx_cc_min[i] = Gxx_cc[i,j]   
for i in range (nq):
    for j in range (nwR):
        if  y[j,i] < -0.9: Gxx_cc[i,j] = Gxx_cc_min[i]
        Gxx_cc[i,j] = Gxx_cc[i,j] / kF * ( mn * 12 )

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rxx_cc_1b[:,i,2]/Gxx_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rxx_cc_1b[:,i,1]/Gxx_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rxx_cc_1b[:,i,0]/Gxx_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
plt.legend(loc=1, ncol=2)
plt.show()  
data=np.array([y[:,4],Rxx_cc_1b[:,4,0]/Gxx_cc[4,:],Rxx_cc_1b[:,4,2]/Gxx_cc[4,:],Rxx_cc_1b[:,4,1]/Gxx_cc[4,:],
               y[:,5],Rxx_cc_1b[:,5,0]/Gxx_cc[5,:],Rxx_cc_1b[:,5,2]/Gxx_cc[5,:],Rxx_cc_1b[:,5,1]/Gxx_cc[5,:],
               y[:,6],Rxx_cc_1b[:,6,0]/Gxx_cc[6,:],Rxx_cc_1b[:,6,2]/Gxx_cc[6,:],Rxx_cc_1b[:,6,1]/Gxx_cc[6,:]])
data = data.T
np.savetxt('F_xx_1b.dat', data)

# %%
Rxx_cc_1b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], Rxx_cc_1b[:,6,2]/Gxx_cc[6,:])
Rxx_cc_1b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], Rxx_cc_1b[:,5,2]/Gxx_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        Rxx_cc_1b[i,j,0] = Rxx_cc_1b_interpolate_600(y[i,j])*Gxx_cc[j,i]
        Rxx_cc_1b[i,j,2] = Rxx_cc_1b_interpolate_700(y[i,j])*Gxx_cc[j,i]
        err = 2 * (Rxx_cc_1b[i,j,2] - Rxx_cc_1b[i,j,0])
        Rxx_cc_1b[i,j,1] = Rxx_cc_1b[i,j,2] + err
        Rxx_cc_1b[i,j,0] = Rxx_cc_1b[i,j,2] - err
        if y[i,j] < -1.4:
            Rxx_cc_1b[i,j,:] = 0
        for k in range(3):
            if Rxx_cc_1b[i,j,k] < 0:  Rxx_cc_1b[i,j,k] = 0

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,nq):
    plt.plot(y[:,i], Rxx_cc_1b[:,i,2]/Gxx_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rxx_cc_1b[:,i,1]/Gxx_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rxx_cc_1b[:,i,0]/Gxx_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3.)
plt.legend(loc=1, ncol=2)
plt.show()  
data=np.array([y[:,4],Rxx_cc_1b[:,4,0]/Gxx_cc[4,:],Rxx_cc_1b[:,4,2]/Gxx_cc[4,:],Rxx_cc_1b[:,4,1]/Gxx_cc[4,:],
               y[:,5],Rxx_cc_1b[:,5,0]/Gxx_cc[5,:],Rxx_cc_1b[:,5,2]/Gxx_cc[5,:],Rxx_cc_1b[:,5,1]/Gxx_cc[5,:],
               y[:,6],Rxx_cc_1b[:,6,0]/Gxx_cc[6,:],Rxx_cc_1b[:,6,2]/Gxx_cc[6,:],Rxx_cc_1b[:,6,1]/Gxx_cc[6,:]])
data = data.T
np.savetxt('F_xx_1b.dat', data)

# %% [markdown]
# ## $R_{xx}$ one+two body

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rxx_cc_12b[:,i,2]/Gxx_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rxx_cc_12b[:,i,1]/Gxx_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rxx_cc_12b[:,i,0]/Gxx_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3)
plt.legend(loc=1, ncol=2)
plt.show()  
data=np.array([y[:,4],Rxx_cc_12b[:,4,0]/Gxx_cc[4,:],Rxx_cc_12b[:,4,2]/Gxx_cc[4,:],Rxx_cc_12b[:,4,1]/Gxx_cc[4,:],
               y[:,5],Rxx_cc_12b[:,5,0]/Gxx_cc[5,:],Rxx_cc_12b[:,5,2]/Gxx_cc[5,:],Rxx_cc_12b[:,5,1]/Gxx_cc[5,:],
               y[:,6],Rxx_cc_12b[:,6,0]/Gxx_cc[6,:],Rxx_cc_12b[:,6,2]/Gxx_cc[6,:],Rxx_cc_12b[:,6,1]/Gxx_cc[6,:]])
data = data.T
np.savetxt('F_xx_12b.dat', data)

# %%
Rxx_cc_12b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], Rxx_cc_12b[:,6,2]/Gxx_cc[6,:])
Rxx_cc_12b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], Rxx_cc_12b[:,5,2]/Gxx_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        Rxx_cc_12b[i,j,0] = Rxx_cc_12b_interpolate_600(y[i,j])*Gxx_cc[j,i]
        Rxx_cc_12b[i,j,2] = Rxx_cc_12b_interpolate_700(y[i,j])*Gxx_cc[j,i]
        err = 2 * (Rxx_cc_12b[i,j,2] - Rxx_cc_12b[i,j,0])
        Rxx_cc_12b[i,j,1] = Rxx_cc_12b[i,j,2] + err
        Rxx_cc_12b[i,j,0] = Rxx_cc_12b[i,j,2] - err
        if y[i,j] < -1.4:
            Rxx_cc_12b[i,j,:] = 0
        for k in range(3):
            if Rxx_cc_12b[i,j,k] < 0:  Rxx_cc_12b[i,j,k] = 0

# %% [markdown]
# ## $R_{xy}$ one body

# %%
Gxy_cc = np.zeros((nq,nwR))
Gxy_cc_min = np.zeros(nq)
for i in range (nq):
    first_time = 1
    Q2qe = abs(qR[i]**2 - wqe[i]**2)
    Ges = ges_interpolate(Q2qe)
    Gev = gev_interpolate(Q2qe)
    Gmv = gmv_interpolate(Q2qe)
    Gms = gms_interpolate(Q2qe)
    GA =  ga_interpolate(Q2qe)
    gps = GA / (mpi**2 + Q2qe)  
    Gen = (Ges - Gev) / 2
    Gep = (Ges + Gev) / 2
    Gmn = (Gms - Gmv) / 2
    Gmp = (Gms + Gmv) / 2
    for j in range (nwR):
        wj = wR[j]
        if wR[j] > qR[i] - 10:
            wj = qR[i] - 10
        Q2j = abs(qR[i]**2 - wj**2)
        Gevj = gev_interpolate(Q2j)
        GAj = ga_interpolate(Q2j)
        pG = mn/qR[i]*(wR[j]-qR[i]**2/2/mn-eps)
        if pG > kF: pG = kF
        Gxy_cc[i,j] = (-(GA*(Gmn-Gmp)*qR[i]*(kF**2-8*mn**2+3*pG**2+4*pG*qR[i]+2*qR[i]**2))/(8*mn**3))/qR[i]
        Gxy_cc[i,j] = Gxy_cc[i,j]*Gevj/Gev*GAj/GA
        if  y[j,i] > -0.9 and first_time == 1:
            first_time = 0
            Gxy_cc_min[i] = Gxy_cc[i,j]   
for i in range (nq):
    for j in range (nwR):
        if  y[j,i] < -0.9: Gxy_cc[i,j] = Gxy_cc_min[i]        
        Gxy_cc[i,j] = Gxy_cc[i,j] / kF * ( mn * 12 )

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,7):
    plt.plot(y[:,i], Rxy_cc_1b[:,i,2]/Gxy_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rxy_cc_1b[:,i,1]/Gxy_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rxy_cc_1b[:,i,0]/Gxy_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3)
plt.legend(loc=1, ncol=2)
plt.show() 
data=np.array([y[:,4],Rxy_cc_1b[:,4,0]/Gxy_cc[4,:],Rxy_cc_1b[:,4,2]/Gxy_cc[4,:],Rxy_cc_1b[:,4,1]/Gxy_cc[4,:],
               y[:,5],Rxy_cc_1b[:,5,0]/Gxy_cc[5,:],Rxy_cc_1b[:,5,2]/Gxy_cc[5,:],Rxy_cc_1b[:,5,1]/Gxy_cc[5,:],
               y[:,6],Rxy_cc_1b[:,6,0]/Gxy_cc[6,:],Rxy_cc_1b[:,6,2]/Gxy_cc[6,:],Rxy_cc_1b[:,6,1]/Gxy_cc[6,:]])
data = data.T
np.savetxt('F_xy_1b.dat', data)

# %%
Rxy_cc_1b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], Rxy_cc_1b[:,6,2]/Gxy_cc[6,:])
Rxy_cc_1b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], Rxy_cc_1b[:,5,2]/Gxy_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        Rxy_cc_1b[i,j,0] = Rxy_cc_1b_interpolate_600(y[i,j])*Gxy_cc[j,i]
        Rxy_cc_1b[i,j,2] = Rxy_cc_1b_interpolate_700(y[i,j])*Gxy_cc[j,i]
        err = 2 * (Rxy_cc_1b[i,j,2] - Rxy_cc_1b[i,j,0])
        Rxy_cc_1b[i,j,1] = Rxy_cc_1b[i,j,2] + err
        Rxy_cc_1b[i,j,0] = Rxy_cc_1b[i,j,2] - err
        if y[i,j] < -1.4:
            Rxy_cc_1b[i,j,:] = 0

# %% [markdown]
# ## $R_{xy}$ one+two body

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(6, 4), dpi=160, facecolor='w', edgecolor='k')
for i in range (4,25):
    plt.plot(y[:,i], Rxy_cc_12b[:,i,2]/Gxy_cc[i,:], color=palette(i), label=qR[i], linestyle='-')
    plt.plot(y[:,i], Rxy_cc_12b[:,i,1]/Gxy_cc[i,:], color=palette(i), linestyle='--')
    plt.plot(y[:,i], Rxy_cc_12b[:,i,0]/Gxy_cc[i,:], color=palette(i), linestyle='-.')
plt.xlim(-1.5,3)
plt.legend(loc=1, ncol=2)
plt.show() 
data=np.array([y[:,4],Rxy_cc_12b[:,4,0]/Gxy_cc[4,:],Rxy_cc_12b[:,4,2]/Gxy_cc[4,:],Rxy_cc_12b[:,4,1]/Gxy_cc[4,:],
               y[:,5],Rxy_cc_12b[:,5,0]/Gxy_cc[5,:],Rxy_cc_12b[:,5,2]/Gxy_cc[5,:],Rxy_cc_12b[:,5,1]/Gxy_cc[5,:],
               y[:,6],Rxy_cc_12b[:,6,0]/Gxy_cc[6,:],Rxy_cc_12b[:,6,2]/Gxy_cc[6,:],Rxy_cc_12b[:,6,1]/Gxy_cc[6,:]])
data = data.T
np.savetxt('F_xy_12b.dat', data)

# %%
Rxy_cc_12b_interpolate_700 = interpolate.InterpolatedUnivariateSpline(y[:,6], Rxy_cc_12b[:,6,2]/Gxy_cc[6,:])
Rxy_cc_12b_interpolate_600 = interpolate.InterpolatedUnivariateSpline(y[:,5], Rxy_cc_12b[:,5,2]/Gxy_cc[5,:])
for j in range (7,nq):
    for i in range (nwR):
        Rxy_cc_12b[i,j,0] = Rxy_cc_12b_interpolate_600(y[i,j])*Gxy_cc[j,i]
        Rxy_cc_12b[i,j,2] = Rxy_cc_12b_interpolate_700(y[i,j])*Gxy_cc[j,i]
        err = 2 * (Rxy_cc_12b[i,j,2] - Rxy_cc_12b[i,j,0])
        Rxy_cc_12b[i,j,1] = Rxy_cc_12b[i,j,2] + err
        Rxy_cc_12b[i,j,0] = Rxy_cc_12b[i,j,2] - err
        if y[i,j] < -1.4:
            Rxy_cc_12b[i,j,:] = 0

# %% [markdown]
# ## Interpolation
# Now we interpolate all response functions and plot them

# %%
def y_int_nr(wr,qr):
    return mn/qr/kF*(wr-qr**2/2/mn-eps)
def w_inv_nr(y,qr):
    return y*qr*kF/mn+qr**2/2/mn+eps

ny=100
ylin=np.linspace(-1.9, 3, ny)



def interp_responses_nr(nq,ny,nwR,qR,ylin,wR,RL):
    y=np.zeros((nwR,nq))
    RL_int_y=np.zeros((ny,nq))
    RL_int_q=np.zeros((ny))
    for i in range (nq):
        for j in range (nwR):
            y[j,i]= y_int_nr(wR[j],qR[i])  
        RL_int_w = InterpolatedUnivariateSpline(y[:,i],RL[:,i],k=3)
        for j in range (ny):
            if(ylin[j]<y[nwR-1,i] and ylin[j]> y[0,i]):
                RL_int_y[j,i]=RL_int_w(ylin[j])
    RL_int_yq = interpolate.RectBivariateSpline(ylin, qR,RL_int_y)
    return RL_int_yq


R00_int_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R00_cc_1b[:,:,2])
R00_int_min_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R00_cc_1b[:,:,0])
R00_int_max_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R00_cc_1b[:,:,1])

R0z_int_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R0z_cc_1b[:,:,2])
R0z_int_min_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R0z_cc_1b[:,:,0])
R0z_int_max_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R0z_cc_1b[:,:,1])

Rzz_int_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rzz_cc_1b[:,:,2])
Rzz_int_min_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rzz_cc_1b[:,:,0])
Rzz_int_max_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rzz_cc_1b[:,:,1])

Rxx_int_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxx_cc_1b[:,:,2])
Rxx_int_min_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxx_cc_1b[:,:,0])
Rxx_int_max_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxx_cc_1b[:,:,1])

Rxy_int_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxy_cc_1b[:,:,2])
Rxy_int_min_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxy_cc_1b[:,:,0])
Rxy_int_max_yq_1b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxy_cc_1b[:,:,1])

###

R00_int_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R00_cc_12b[:,:,2])
R00_int_min_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R00_cc_12b[:,:,0])
R00_int_max_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R00_cc_12b[:,:,1])

R0z_int_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R0z_cc_12b[:,:,2])
R0z_int_min_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R0z_cc_12b[:,:,0])
R0z_int_max_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,R0z_cc_12b[:,:,1])

Rzz_int_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rzz_cc_12b[:,:,2])
Rzz_int_min_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rzz_cc_12b[:,:,0])
Rzz_int_max_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rzz_cc_12b[:,:,1])

Rxx_int_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxx_cc_12b[:,:,2])
Rxx_int_min_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxx_cc_12b[:,:,0])
Rxx_int_max_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxx_cc_12b[:,:,1])

Rxy_int_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxy_cc_12b[:,:,2])
Rxy_int_min_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxy_cc_12b[:,:,0])
Rxy_int_max_yq_12b= interp_responses_nr(nq,ny,nwR,qR,ylin,wR,Rxy_cc_12b[:,:,1])

# %%
from matplotlib.pyplot import figure
palette = plt.get_cmap('Set1')
figure(num=None, figsize=(8, 6), dpi=120, facecolor='w', edgecolor='k')
for i in range (10):
    plt.plot(ylin, R00_int_yq_1b(ylin,qR[i]), color=palette(i), label=qR[i])
 #  plt.fill_between(ylin, R00_int_yq_1b(ylin,qR[i]), R00_int_yq_1b(ylin,qR[i]),alpha=0.4,color=palette(i))
#plt.plot(w, R00_cc_1b_int_min(w,q), 'purple', linestyle='-.')
plt.plot(ylin, R00_int_yq_1b(ylin,450.0), 'purple', linestyle='--')
#plt.plot(w, R00_cc_1b_int(w,q), 'purple', linestyle='-')
#plt.xlim(0, 1000)
plt.legend(loc=1, ncol=2)
plt.show()

# %%
# you can plot the other channels and compare with the different form factors

# %%
hbar=197.327
ml=105.6584
mn=939.
GF=1.1803*10**(-11)
G=GF*0.97425
mn=939.
def dsig_compute_ys(wi,E,cos):
    Ep=E-wi
    W=E+Ep
    k=E
    kp=np.sqrt(Ep**2-ml**2)
    Q=np.sqrt(k**2+kp**2+2*k*kp*cos)
    q=np.sqrt(k**2+kp**2-2*k*kp*cos)
    kz=(ml**2-wi**2+q**2+2*E*wi)/2/q
    kx=np.sqrt(E**2-kz**2)
    Qz=2*kz-q
    Qx=2*kx
    L_CC=W**2-q**2-ml**2
    L_CL=(-W*Qz+wi*q)
    L_LL=Qz**2-wi**2+ml**2
    L_T=Qx**2/2.-(wi**2-q**2)+ml**2
    L_Tp=W*q-wi*Qz 
    sig_CC=G**2/4./np.pi**2*kp/2./E
    N_CC=sig_CC*L_CC
    N_CL=sig_CC*L_CL
    N_LL=sig_CC*L_LL
    N_T=sig_CC*L_T
    N_Tp=sig_CC*L_Tp
    yi=y_int_nr(wi,q)
    R00_1b_i=R00_int_yq_1b(yi,q)
    R00_1b_i_err=np.abs(R00_int_max_yq_1b(yi,q)-R00_int_min_yq_1b(yi,q)) 
    R0z_1b_i=R0z_int_yq_1b(yi,q)
    R0z_1b_i_err=np.abs(R0z_int_max_yq_1b(yi,q)-R0z_int_min_yq_1b(yi,q))
    Rzz_1b_i=Rzz_int_yq_1b(yi,q)
    Rzz_1b_i_err=np.abs(Rzz_int_max_yq_1b(yi,q)-Rzz_int_min_yq_1b(yi,q))
    Rxx_1b_i=Rxx_int_yq_1b(yi,q)
    Rxx_1b_i_err=np.abs(Rxx_int_max_yq_1b(yi,q)-Rxx_int_min_yq_1b(yi,q))
    Rxy_1b_i=Rxy_int_yq_1b(yi,q)
    Rxy_1b_i_err=np.abs(Rxy_int_max_yq_1b(yi,q)-Rxy_int_min_yq_1b(yi,q))
    R00_12b_i=R00_int_yq_12b(yi,q)
    R00_12b_i_err=np.abs(R00_int_max_yq_12b(yi,q)-R00_int_min_yq_12b(yi,q)) 
    R0z_12b_i=R0z_int_yq_12b(yi,q)
    R0z_12b_i_err=np.abs(R0z_int_max_yq_12b(yi,q)-R0z_int_min_yq_12b(yi,q))
    Rzz_12b_i=Rzz_int_yq_12b(yi,q)
    Rzz_12b_i_err=np.abs(Rzz_int_max_yq_12b(yi,q)-Rzz_int_min_yq_12b(yi,q))
    Rxx_12b_i=Rxx_int_yq_12b(yi,q)
    Rxx_12b_i_err=np.abs(Rxx_int_max_yq_12b(yi,q)-Rxx_int_min_yq_12b(yi,q))
    Rxy_12b_i=Rxy_int_yq_12b(yi,q)
    Rxy_12b_i_err=np.abs(Rxy_int_max_yq_12b(yi,q)-Rxy_int_min_yq_12b(yi,q))

    if wi > q:
        print('problem, wi > q',wi, q)
    dsig_nu_1b=np.zeros(3)
    dsig_nubar_1b=np.zeros(3)
    dsig_nu_12b=np.zeros(3)
    dsig_nubar_12b=np.zeros(3)
#    if wi < q**2/2/mn+0.5*eps+q*kF/mn:
    if q < 2000:
        dsig_nu=N_CC*R00_1b_i+N_CL*R0z_1b_i+N_LL*Rzz_1b_i+N_T*Rxx_1b_i-N_Tp*Rxy_1b_i
        dsig_nu_e=np.sqrt(N_CC**2*R00_1b_i_err**2+N_CL**2*R0z_1b_i_err**2+N_LL**2*Rzz_1b_i_err**2
                   +N_T**2*Rxx_1b_i_err**2+N_Tp**2*Rxy_1b_i_err**2)
        dsig_nubar=N_CC*R00_1b_i+N_CL*R0z_1b_i+N_LL*Rzz_1b_i+N_T*Rxx_1b_i+N_Tp*Rxy_1b_i
        dsig_nubar_e=dsig_nu_e
        dsig_nu_1b[0]=dsig_nu
        dsig_nu_1b[1]=dsig_nu-dsig_nu_e/2
        dsig_nu_1b[2]=dsig_nu+dsig_nu_e/2
        dsig_nubar_1b[0]=dsig_nubar
        dsig_nubar_1b[1]=dsig_nubar-dsig_nubar_e/2
        dsig_nubar_1b[2]=dsig_nubar+dsig_nubar_e/2  
        dsig_nu=N_CC*R00_12b_i+N_CL*R0z_12b_i+N_LL*Rzz_12b_i+N_T*Rxx_12b_i-N_Tp*Rxy_12b_i
        dsig_nu_e=np.sqrt(N_CC**2*R00_12b_i_err**2+N_CL**2*R0z_12b_i_err**2+N_LL**2*Rzz_12b_i_err**2
                      +N_T**2*Rxx_12b_i_err**2+N_Tp**2*Rxy_12b_i_err**2)
        dsig_nubar=N_CC*R00_12b_i+N_CL*R0z_12b_i+N_LL*Rzz_12b_i+N_T*Rxx_12b_i+N_Tp*Rxy_12b_i    
        dsig_nubar_e=dsig_nu_e
        dsig_nu_12b[0]=dsig_nu
        dsig_nu_12b[1]=dsig_nu-dsig_nu_e/2
        dsig_nu_12b[2]=dsig_nu+dsig_nu_e/2
        dsig_nubar_12b[0]=dsig_nubar
        dsig_nubar_12b[1]=dsig_nubar-dsig_nubar_e/2
        dsig_nubar_12b[2]=dsig_nubar+dsig_nubar_e/2
        dsig_nu_1b=dsig_nu_1b*hbar**2*2*np.pi 
        dsig_nubar_1b=dsig_nubar_1b*hbar**2*2*np.pi
        dsig_nu_12b=dsig_nu_12b*hbar**2*2*np.pi #fm**2 MeV**-1
        dsig_nubar_12b=dsig_nubar_12b*hbar**2*2*np.pi
    return dsig_nu_1b, dsig_nubar_1b, dsig_nu_12b, dsig_nubar_12b

# %%
wmax=2000
nw=1000
w=np.linspace(0, wmax, nw)

# %%
E=1000.
theta=30.
theta=theta*np.pi/180.
dsig_nu_1b=np.zeros((nw,3))
dsig_nu_12b=np.zeros((nw,3))

dsig_nubar_1b=np.zeros((nw,3))
dsig_nubar_12b=np.zeros((nw,3))

w=np.linspace(0, E-ml, nw)

for i in range (nw):
    dsig_nu_1b[i,:], dsig_nubar_1b[i,:], dsig_nu_12b[i,:], dsig_nubar_12b[i,:] = dsig_compute_ys(w[i],E,np.cos(theta))

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(5, 4), dpi=120, facecolor='w', edgecolor='k')
plt.plot(w, dsig_nu_1b[:,0],'red',linestyle='--', label=r'$\nu$ - GFMC 1b')
plt.fill_between(w, dsig_nu_1b[:,1], dsig_nu_1b[:,2], alpha=0.4,color='red')
plt.plot(w, dsig_nubar_1b[:,0],'black',linestyle='--', label=r'$\bar{\nu}$ - GFMC 1b' )
plt.fill_between(w, dsig_nubar_1b[:,1], dsig_nubar_1b[:,2], alpha=0.4,color='black')
plt.plot(w, dsig_nu_12b[:,0],'red', label=r'$\nu$ - GFMC 12b')
plt.fill_between(w, dsig_nu_12b[:,1], dsig_nu_12b[:,2], alpha=0.4,color='red')
plt.plot(w, dsig_nubar_12b[:,0],'black', label=r'$\bar{\nu}$ - GFMC 12b')
plt.fill_between(w, dsig_nubar_12b[:,1], dsig_nubar_12b[:,2], alpha=0.4,color='black')
plt.legend(loc=1, ncol=1)
plt.title(r'$E=1000$ MeV,  $\theta = 30^\circ$')
plt.xlabel(r'$\omega$')
plt.ylabel(r'$\frac{d\sigma}{dT_\mu d\cos(\theta_\mu)}$ fm$^2$ MeV$^{-1}$')
plt.xlim(0, 500)
plt.show()

# %%
fname_nu = 'flux_nu.dat'
fname_nubar = 'flux_nubar.dat'
data_nu = np.loadtxt(fname_nu, unpack=True, skiprows=9)
data_nubar = np.loadtxt(fname_nubar, unpack=True, skiprows=9)
nbin= len(data_nu[1,:])

# Setup fine grid
nflux_MB=800
E_flux_min_MB=0
E_flux_max_MB=4#max(data_nu[1,:])
E_flux_MB=np.linspace(E_flux_min_MB, E_flux_max_MB, nflux_MB)
E_flux_MB=E_flux_MB*1000
dE_flux_MB=E_flux_MB[1]-E_flux_MB[0]
nu_flux_MB=np.zeros(nflux_MB)
nubar_flux_MB=np.zeros(nflux_MB)

# Interpolate flux on fine grid
E_flux_read=np.zeros(nbin)
nu_flux_read=np.zeros(nbin)
nubar_flux_read=np.zeros(nbin)
E_flux_read[:]=(data_nu[0,:]+data_nu[1,:])/2*1000
nu_flux_read[:]=data_nu[2,:]
nubar_flux_read[:]=data_nubar[3,:]
nu_flux_MB_interpolate=interpolate.UnivariateSpline(E_flux_read, nu_flux_read, s=0)
nubar_flux_MB_interpolate=interpolate.UnivariateSpline(E_flux_read, nubar_flux_read, s=0)
for i in range(nflux_MB):
    nu_flux_MB[i] = nu_flux_MB_interpolate(E_flux_MB[i])
    nubar_flux_MB[i] = nubar_flux_MB_interpolate(E_flux_MB[i])
norm_nu_MB=np.trapz(nu_flux_MB,E_flux_MB)
norm_nubar_MB=np.trapz(nubar_flux_MB,E_flux_MB)
E_flux_MB=E_flux_MB
nu_flux_MB=nu_flux_MB/norm_nu_MB
nubar_flux_MB=nubar_flux_MB/norm_nubar_MB

# %%
def mpgrid(start,stop,nstep):
    dx=(stop-start)/nstep
    grid=np.zeros(nstep)
    for i in range(nstep):
        grid[i]=start+(i+0.5)*dx
    return  grid

# %%
n_Tmu=100
Tmu_max=2000
Tmu_min=10
Tmu=np.linspace(Tmu_min, Tmu_max, n_Tmu)
ntheta=10
cos_theta_flux=mpgrid(0.9, 1.0, ntheta)
dsig_nu_flux_1b=np.zeros((n_Tmu,3,3))
dsig_nubar_flux_1b=np.zeros((n_Tmu,3,3))
dsig_nu_flux_12b=np.zeros((n_Tmu,3,3))
dsig_nubar_flux_12b=np.zeros((n_Tmu,3,3))
for i in range (n_Tmu):
    for j in range (nflux_MB):
        E = E_flux_MB[j]
        w_i= E - Tmu[i] - ml
        if w_i > 0 and E > 0: 
            for k in range (ntheta):
                dsig_nu_1b, dsig_nubar_1b, dsig_nu_12b, dsig_nubar_12b = dsig_compute_ys(w_i,E,cos_theta_flux[k])
                dsig_nu_flux_1b[i,:,0] = dsig_nu_flux_1b[i,:,0] +  dsig_nu_1b[:] * nu_flux_MB[j] * dE_flux_MB
                dsig_nu_flux_12b[i,:,0] = dsig_nu_flux_12b[i,:,0] +  dsig_nu_12b[:] * nu_flux_MB[j] * dE_flux_MB
                dsig_nubar_flux_1b[i,:,0] = dsig_nubar_flux_1b[i,:,0] +  dsig_nubar_1b[:] * nubar_flux_MB[j] * dE_flux_MB
                dsig_nubar_flux_12b[i,:,0] = dsig_nubar_flux_12b[i,:,0] +  dsig_nubar_12b[:] * nubar_flux_MB[j] * dE_flux_MB
        
                if E < 800:
                    dsig_nu_flux_1b[i,:,2] = dsig_nu_flux_1b[i,:,2] +  dsig_nu_1b[:] * nu_flux_MB[j] * dE_flux_MB
                    dsig_nu_flux_12b[i,:,2] = dsig_nu_flux_12b[i,:,2] +  dsig_nu_12b[:] * nu_flux_MB[j] * dE_flux_MB
                    dsig_nubar_flux_1b[i,:,2] = dsig_nubar_flux_1b[i,:,2] +  dsig_nubar_1b[:] * nubar_flux_MB[j] * dE_flux_MB
                    dsig_nubar_flux_12b[i,:,2] = dsig_nubar_flux_12b[i,:,2] +  dsig_nubar_12b[:] * nubar_flux_MB[j] * dE_flux_MB   
dsig_nu_flux_1b_MB_095=dsig_nu_flux_1b/ntheta*10**(-26)/6
dsig_nubar_flux_1b_MB_095=dsig_nubar_flux_1b/ntheta*10**(-26)/6
dsig_nu_flux_12b_MB_095=dsig_nu_flux_12b/ntheta*10**(-26)/6
dsig_nubar_flux_12b_MB_095=dsig_nubar_flux_12b/ntheta*10**(-26)/6
Tmu_MB_095=Tmu

# %%
fname='MB/exp_nu_MB_095.dat'
Tmu_nu_data,dsig_CC_nu_data,dsig_CC_nu_err=np.loadtxt(fname,unpack=True)

# %%
import matplotlib.pyplot as plt
figure(num=None, figsize=(5, 4), dpi=120, facecolor='w', edgecolor='k')
plt.errorbar(Tmu_nu_data, dsig_CC_nu_data, yerr=dsig_CC_nu_err, fmt="none", ecolor='red')
plt.plot(Tmu_nu_data, dsig_CC_nu_data,'ro')
plt.plot(Tmu_MB_095, dsig_nu_flux_1b_MB_095[:,0,0], 'blue', label='1b')
plt.fill_between(Tmu_MB_095, dsig_nu_flux_1b_MB_095[:,1,0], dsig_nu_flux_1b_MB_095[:,2,0], alpha=0.25,color='blue')
plt.plot(Tmu_MB_095, dsig_nu_flux_12b_MB_095[:,0,0], 'black', label='12b')
plt.fill_between(Tmu_MB_095, dsig_nu_flux_12b_MB_095[:,1,0], dsig_nu_flux_12b_MB_095[:,2,0], alpha=0.25,color='black')

plt.xlim(0, 2000)
plt.legend(loc=1, ncol=1)
plt.title(r'$\nu - ^{12}$C   $0.9<\cos(\theta)<1.0$')
plt.xlabel(r'$T_\mu$')
plt.ylabel(r'$\frac{d\sigma}{dT_\mu d\cos(\theta_\mu)}$ cm$^2$ MeV$^{-1}$')
plt.show()

# %%
n_Tmu=100
Tmu_max=2000
Tmu_min=10
Tmu=np.linspace(Tmu_min, Tmu_max, n_Tmu)
ntheta=10
cos_theta_flux=mpgrid(0.8, 0.9, ntheta)
dsig_nu_flux_1b=np.zeros((n_Tmu,3,3))
dsig_nubar_flux_1b=np.zeros((n_Tmu,3,3))
dsig_nu_flux_12b=np.zeros((n_Tmu,3,3))
dsig_nubar_flux_12b=np.zeros((n_Tmu,3,3))
for i in range (n_Tmu):
    for j in range (nflux_MB):
        E = E_flux_MB[j]
        w_i= E - Tmu[i] - ml
        if w_i > 0 and E > 0: 
            for k in range (ntheta):
                dsig_nu_1b, dsig_nubar_1b, dsig_nu_12b, dsig_nubar_12b = dsig_compute_ys(w_i,E,cos_theta_flux[k])
                dsig_nu_flux_1b[i,:,0] = dsig_nu_flux_1b[i,:,0] +  dsig_nu_1b[:] * nu_flux_MB[j] * dE_flux_MB
                dsig_nu_flux_12b[i,:,0] = dsig_nu_flux_12b[i,:,0] +  dsig_nu_12b[:] * nu_flux_MB[j] * dE_flux_MB
                dsig_nubar_flux_1b[i,:,0] = dsig_nubar_flux_1b[i,:,0] +  dsig_nubar_1b[:] * nubar_flux_MB[j] * dE_flux_MB
                dsig_nubar_flux_12b[i,:,0] = dsig_nubar_flux_12b[i,:,0] +  dsig_nubar_12b[:] * nubar_flux_MB[j] * dE_flux_MB
        
                if E < 800:
                    dsig_nu_flux_1b[i,:,2] = dsig_nu_flux_1b[i,:,2] +  dsig_nu_1b[:] * nu_flux_MB[j] * dE_flux_MB
                    dsig_nu_flux_12b[i,:,2] = dsig_nu_flux_12b[i,:,2] +  dsig_nu_12b[:] * nu_flux_MB[j] * dE_flux_MB
                    dsig_nubar_flux_1b[i,:,2] = dsig_nubar_flux_1b[i,:,2] +  dsig_nubar_1b[:] * nubar_flux_MB[j] * dE_flux_MB
                    dsig_nubar_flux_12b[i,:,2] = dsig_nubar_flux_12b[i,:,2] +  dsig_nubar_12b[:] * nubar_flux_MB[j] * dE_flux_MB   
dsig_nu_flux_1b_MB_085=dsig_nu_flux_1b/ntheta*10**(-26)/6
dsig_nubar_flux_1b_MB_085=dsig_nubar_flux_1b/ntheta*10**(-26)/6
dsig_nu_flux_12b_MB_085=dsig_nu_flux_12b/ntheta*10**(-26)/6
dsig_nubar_flux_12b_MB_085=dsig_nubar_flux_12b/ntheta*10**(-26)/6
Tmu_MB_085=Tmu

# %%
fname='MB/exp_nu_MB_085.dat'
Tmu_nu_data,dsig_CC_nu_data,dsig_CC_nu_err=np.loadtxt(fname,unpack=True)

# %%
import matplotlib.pyplot as plt
figure(num=None, figsize=(5, 4), dpi=120, facecolor='w', edgecolor='k')
plt.errorbar(Tmu_nu_data, dsig_CC_nu_data, yerr=dsig_CC_nu_err, fmt="none", ecolor='red')
plt.plot(Tmu_nu_data, dsig_CC_nu_data,'ro')
plt.plot(Tmu_MB_085, dsig_nu_flux_1b_MB_085[:,0,0], 'blue', label='1b')
plt.fill_between(Tmu_MB_085, dsig_nu_flux_1b_MB_085[:,1,0], dsig_nu_flux_1b_MB_085[:,2,0], alpha=0.25,color='blue')
plt.plot(Tmu_MB_085, dsig_nu_flux_12b_MB_085[:,0,0], 'black', label='12b')
plt.fill_between(Tmu_MB_085, dsig_nu_flux_12b_MB_085[:,1,0], dsig_nu_flux_12b_MB_085[:,2,0], alpha=0.25,color='black')

plt.xlim(0, 2000)
plt.legend(loc=1, ncol=1)
plt.title(r'$\nu - ^{12}$C   $0.8<\cos(\theta)<0.9$')
plt.xlabel(r'$T_\mu$')
plt.ylabel(r'$\frac{d\sigma}{dT_\mu d\cos(\theta_\mu)}$ cm$^2$ MeV$^{-1}$')
plt.show()
